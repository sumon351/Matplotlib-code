# %% [markdown]
# # histogram plot

# %%
# basic
import numpy as np
import matplotlib.pyplot as plt
x=np.random.randint(10,60,(50))
print(x)
# Out:
# [50 49 52 36 52 13 21 25 33 21 49 27 18 47 21 45 58 34 18 28 13 37 19 41
#  57 38 11 48 58 48 35 13 13 33 37 22 43 31 24 29 16 23 44 41 30 42 29 53
#  38 55]

# %%
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no)
plt.show()

# %%
# using title and label
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no)
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# using color and edgecolor
import matplotlib.pyplot as plt

no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black')
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# using (bin) parameter for collecting data
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
l=[10,20,30,40,50,60]
plt.hist(no,color='r',edgecolor='black',bins=l)
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# using ('auto') and range
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,'auto',(0,100),color='r',edgecolor='black')
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# using cumulative parameter
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',cumulative=-1)
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# bottom parameter
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',bottom=20)
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# align parameter
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',align='right') # left / mid
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# histogram type (histtype)
# example=step/stepfilled/bar/barstacked
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',histtype='step')
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# orientation='horizontal' and default is vertical
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',orientation='horizontal')
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# rwidth
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',rwidth=0.9)
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# lagarithm table
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',log=True)
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.show()

# %%
# label parameter
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',label='python')
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.axvline(40,color='y',label='line')
plt.legend()
plt.show()

# %%
# grid parameter
import matplotlib.pyplot as plt
no=[50, 51 ,11, 18, 42, 54 ,54, 32, 45, 19, 24, 37, 26, 25, 19, 22, 34 ,30 ,34, 46, 15,13, 43, 41,
 29, 36 ,37, 46, 54, 52, 39, 22, 47, 13, 44, 47, 14, 44, 54 ,34, 42, 27, 54, 40, 12, 49 ,54 ,59,
 48 ,32]
plt.hist(no,color='r',edgecolor='black',label='python')
plt.title('Histogram plot')
plt.xlabel('Python')
plt.ylabel('No')
plt.axvline(40,color='y',label='line')
plt.legend()
plt.grid()
plt.show()
