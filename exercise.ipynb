# %%
import matplotlib.pyplot as plt

# %%
x=['python','c++','java','Mysql']
y=[20,30,22,55]
c=['r','g','y','b']
plt.bar(x,y,width=0.4,color=c,edgecolor='k')
plt.xlabel('Languages',fontsize=15)
plt.ylabel('No of popularity',fontsize=15)
plt.title('Bar plot',fontsize=15)
plt.show()
