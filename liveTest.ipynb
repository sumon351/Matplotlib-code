# %%
# live test 
import matplotlib.pyplot as plt
import numpy as np
x=np.arange(0,11,2)
y=[2,4,6,8,10,12]
plt.plot(x,x+2,color='b',label='x+2')

plt.plot(x,x+3,color='y',label='x+3')
plt.legend(loc=4)
plt.savefig('liveTestOutputImage',dpi=2000)
plt.show()
